# %% [markdown]
# * Question 3가지로부터 Answer를 뽑아냄
# > 신체 검진, 입원 시 기록
# >
# > ChatGPT 5의 답변 내용을 Label로 하였음
#
# * 나중에는 범주에 들어가는 정보 / 들어가지 않은 정보를 어떻게 처리할 지 생각해봐야...
#
# * 들어가는 수치값은 약간 임의로 좀 좋아보이는 걸로 선택했음. 최대한 합리적인 선에서 판단을 했다. -> human expert가 개입해야만 함
#
# * 사망 원인? 부분의 성능은 뒤죽박죽함. 그런데 이건 샘플링으로 수행한 거라... 그리디로 하면 좀 좋아질 수도 있다고 생각함.
# > 순위 매기는 데에 5분 정도...?
#
# * 다중공선성...
# > 변수 간 관련성이 있음. 완전한 다중공선성
# >
# > 시스템 프롬프트에 변수 간 다중공선성이 크다는 점을 넣으면 괜찮다고 봅니다. 네.
#
# * NA 있는 것들은 다 처리.
# > NA가 있다면 그냥 쓰지 않는 것이 더 좋을지도.
# >
# > NA가 없는 방향으로 최대한 만들자. Pair를 만들 때 문제가 좀 많은 것들은 빼버리자.
#
# * 퇴원 시 physical check 값을 넣는 상황이 생김.
