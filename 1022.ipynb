# %% [markdown]
# ## Bandits

# %% [markdown]
# `-` Online Learning and Bandits
#
# * UCB algorithm
# * Thompson Sampling: UCB보다 실무에서 더 적합함
#
# `-` Structured Bandits
#
# * Linear Bandits: Confidennce sequence
#
# `-` Recommended references
#
# * Bandit Algorithms: TOR LATTIMORE

# %% [markdown]
# `-` Generalized Linear Bandits
